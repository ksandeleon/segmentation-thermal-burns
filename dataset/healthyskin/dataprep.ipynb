# %%
import os
from pathlib import Path
import shutil

# Define paths - checking for train/valid/test structure
# Based on your structure: dataset/healthyskin/train, dataset/healthyskin/valid, dataset/healthyskin/test
labels_dirs = []

# Check for train/valid/test splits (same directory level as notebook)
train_labels = Path("./train/labels")
valid_labels = Path("./valid/labels")
test_labels = Path("./test/labels")

if train_labels.exists():
    labels_dirs.append(train_labels)
if valid_labels.exists():
    labels_dirs.append(valid_labels)
if test_labels.exists():
    labels_dirs.append(test_labels)

# Also check old dataset structure (fallback)
dataset_labels = Path("./dataset/labels")
if dataset_labels.exists():
    labels_dirs.append(dataset_labels)

if not labels_dirs:
    print("❌ No label directories found!")
    print("Expected structure:")
    print("  ./train/labels")
    print("  ./valid/labels")
    print("  ./test/labels")
else:
    print(f"✅ Found {len(labels_dirs)} label directories to process:")
    for d in labels_dirs:
        file_count = len(list(d.glob("*.txt")))
        print(f"  - {d} ({file_count} files)")
# Out:
# Found 1 label directories to process
#   - dataset/labels

# %%
def process_label_file(label_path):
    """
    Process a single label file:
    - Keep only lines with class 3 (Healthy-Skin)
    - Change class 3 to class 4
    - Remove all other classes
    
    Returns: (processed_lines, kept_count, removed_count)
    """
    processed_lines = []
    kept_count = 0
    removed_count = 0
    
    with open(label_path, 'r') as f:
        lines = f.readlines()
    
    for line in lines:
        line = line.strip()
        if not line:
            continue
            
        # Split the line to get the class ID (first element)
        parts = line.split()
        if len(parts) < 5:  # YOLO format: class x y w h
            continue
            
        class_id = int(parts[0])
        
        # Keep only Healthy-Skin (class 3)
        if class_id == 3:
            # Change class 3 to class 4
            parts[0] = '4'
            processed_lines.append(' '.join(parts) + '\n')
            kept_count += 1
        else:
            removed_count += 1
    
    return processed_lines, kept_count, removed_count

# Test on one file first
test_file = list(labels_dirs[0].glob("*.txt"))[0] if labels_dirs[0].exists() else None
if test_file:
    print(f"Testing on: {test_file.name}")
    processed, kept, removed = process_label_file(test_file)
    print(f"  Kept {kept} Healthy-Skin annotations")
    print(f"  Removed {removed} other class annotations")
    print(f"  Processed content preview:")
    for line in processed[:3]:
        print(f"    {line.strip()}")
# Out:
# Testing on: erythema-migrans241_png_jpg.rf.94ea5b105f58fd5ef2610a1aedb737f1.txt
#   Kept 0 Healthy-Skin annotations
#   Removed 2 other class annotations
#   Processed content preview:

# %%
def process_all_labels(labels_dirs, dry_run=True):
    """
    Process all label files in the given directories.
    
    Args:
        labels_dirs: List of label directory paths
        dry_run: If True, don't actually modify files (default: True)
    """
    total_files = 0
    total_kept = 0
    total_removed = 0
    files_with_healthy_skin = 0
    empty_files = []
    
    for labels_dir in labels_dirs:
        if not labels_dir.exists():
            print(f"Skipping non-existent directory: {labels_dir}")
            continue
            
        print(f"\nProcessing directory: {labels_dir}")
        label_files = list(labels_dir.glob("*.txt"))
        print(f"Found {len(label_files)} label files")
        
        for label_file in label_files:
            total_files += 1
            processed_lines, kept, removed = process_label_file(label_file)
            
            total_kept += kept
            total_removed += removed
            
            if kept > 0:
                files_with_healthy_skin += 1
                
                if not dry_run:
                    # Write the processed content back
                    with open(label_file, 'w') as f:
                        f.writelines(processed_lines)
            else:
                # File has no healthy skin annotations
                empty_files.append(label_file)
    
    print("\n" + "="*60)
    print("SUMMARY")
    print("="*60)
    print(f"Total files processed: {total_files}")
    print(f"Files with Healthy-Skin: {files_with_healthy_skin}")
    print(f"Files without Healthy-Skin: {len(empty_files)}")
    print(f"Total Healthy-Skin annotations kept (changed to class 4): {total_kept}")
    print(f"Total other class annotations removed: {total_removed}")
    
    if empty_files:
        print(f"\nFiles with no Healthy-Skin annotations (first 10):")
        for f in empty_files[:10]:
            print(f"  - {f.name}")
        if len(empty_files) > 10:
            print(f"  ... and {len(empty_files) - 10} more")
    
    if dry_run:
        print("\n⚠️  DRY RUN MODE - No files were modified")
        print("Set dry_run=False to apply changes")
    else:
        print("\n✅ Files have been updated!")
    
    return empty_files

# Run in dry-run mode first
empty_files = process_all_labels(labels_dirs, dry_run=True)
# Out:
# Processing directory: dataset/labels
# Found 2787 label files
#
# ============================================================
# SUMMARY
# ============================================================
# Total files processed: 2787
# Files with Healthy-Skin: 321
# Files without Healthy-Skin: 2466
# Total Healthy-Skin annotations kept (changed to class 4): 1053
# Total other class annotations removed: 7666
#
# Files with no Healthy-Skin annotations (first 10):
#   - erythema-migrans241_png_jpg.rf.94ea5b105f58fd5ef2610a1aedb737f1.txt
#   - t-eczema-nummular-150_jpg.rf.fe46636f91eec38ffe6f4bb2c172ca4e.txt
#   - sjs-ten-ocular-27__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd_jpg.rf.86b054f2bf30b15cc2eb724a28e6ac7c.txt
#   - shutterstock_484652500-scaled-Copy_jpg.rf.fb16379e1d60b6f3a4cfe0782fb6977a.txt
#   - 05keratosisPilaris010120_jpeg_jpg.rf.f2caf77b5cb9aa8139f7418bb4b40e53.txt
#   - viral-wart-22__WatermarkedWyJXYXRlcm1hcmtlZCJd-1-Copy_jpg.rf.811fd079b974c99f5e7541a30ab7056c.txt
#   - KP-9-_jpg.rf.97c005e335903eb4e0f300ba5d78e854.txt
#   - t-warts-32_jpg.rf.ef33dbdbc399394e36710036b855a6c7.txt
#   - erythema-migrans264_jpg.rf.de38562922793f22532dac2407097732.txt
#   - acne-scarring-300x300-Copy_jpg.rf.628bf11fedc1ce08cae0095f389a72c4.txt
#   ... and 2456 more
#
# ⚠️  DRY RUN MODE - No files were modified
# Set dry_run=False to apply changes

# %%
# EXECUTE THIS CELL TO APPLY THE CHANGES
# Uncomment the line below to actually modify the files

empty_files = process_all_labels(labels_dirs, dry_run=False)


def remove_empty_files(empty_label_files):
    """Remove label files and corresponding images that have no healthy skin"""
    for label_file in empty_label_files:
        # Remove label file
        print(f"Removing: {label_file}")
        label_file.unlink()
        
        # Find and remove corresponding image
        image_dir = label_file.parent.parent / "images"
        image_name = label_file.stem  # filename without .txt
        
        for ext in ['.jpg', '.jpeg', '.png', '.JPG', '.JPEG', '.PNG']:
            image_file = image_dir / f"{image_name}{ext}"
            if image_file.exists():
                print(f"Removing: {image_file}")
                image_file.unlink()
                break

# Uncomment to remove files without healthy skin
remove_empty_files(empty_files)
# Out:
# Processing directory: dataset/labels
# Found 2787 label files
#
# ============================================================
# SUMMARY
# ============================================================
# Removing: dataset/images/erythema-migrans264_jpg.rf.de38562922793f22532dac2407097732.jpg
# Removing: dataset/labels/acne-scarring-300x300-Copy_jpg.rf.628bf11fedc1ce08cae0095f389a72c4.txt
# Removing: dataset/images/acne-scarring-300x300-Copy_jpg.rf.628bf11fedc1ce08cae0095f389a72c4.jpg
# Removing: dataset/labels/chicken-skin_jpg.rf.6895a85c7fd4248dfc6dd1a6c05ee382.txt
# Removing: dataset/images/chicken-skin_jpg.rf.6895a85c7fd4248dfc6dd1a6c05ee382.jpg
# Removing: dataset/labels/KP-9-_jpg.rf.be352a1cc42f9235b46faf8b104b73e8.txt
# Removing: dataset/images/KP-9-_jpg.rf.be352a1cc42f9235b46faf8b104b73e8.jpg
# Removing: dataset/labels/erythema-migrans280_png_jpg.rf.b77e78ca592341094d8ed12ea0327a1b.txt
# Removing: dataset/images/erythema-migrans280_png_jpg.rf.b77e78ca592341094d8ed12ea0327a1b.jpg
# Removing: dataset/labels/viral-wart-15__WatermarkedWyJXYXRlcm1hcmtlZCJd-1-Copy_jpg.rf.de98e5996f154617d4678a4f4ec0432e.txt
# Removing: dataset/images/viral-wart-15__WatermarkedWyJXYXRlcm1hcmtlZCJd-1-Copy_jpg.rf.de98e5996f154617d4678a4f4ec0432e.jpg
# Removing: dataset/labels/KP-22-_jpg.rf.dfc6fb2b26ab3dfbd5deca1d7fbd32d9.txt
# Removing: dataset/images/KP-22-_jpg.rf.dfc6fb2b26ab3dfbd5deca1d7fbd32d9.jpg
# Removing: dataset/labels/t-eczema-impetiginized-12_jpg.rf.4d2f8175220262b8d469e8bc07794c2d.txt
# Removing: dataset/images/t-eczema-impetiginized-12_jpg.rf.4d2f8175220262b8d469e8bc07794c2d.jpg
# Removing: dataset/labels/6_150_jpg.rf.83dd24b9172c6fd1efcdcf2741c240e8.txt
# Removing: dataset/images/6_150_jpg.rf.83dd24b9172c6fd1efcdcf2741c240e8.jpg
# Removing: dataset/labels/OIP-13-Copy_jpg.rf.c54e590981575c973dbfb2b8e7906907.txt
# Removing: dataset/images/OIP-13-Copy_jpg.rf.c54e590981575c973dbfb2b8e7906907.jpg
# Removing: dataset/labels/3031__WatermarkedWyJXYXRlcm1hcmtlZCJd_jpg.rf.4f4072132f703cc0d5b02f7b8859cc2f.txt
# Removing: dataset/images/3031__WatermarkedWyJXYXRlcm1hcmtlZCJd_jpg.rf.4f4072132f703cc0d5b02f7b8859cc2f.jpg
# Removing: dataset/labels/image-jpg-e82341306e199844c244558307a055e0-1-Copy_jpg.rf.f67a82d6ac74bc06ea8bf3ca504c4237.txt
# Removing: dataset/images/image-jpg-e82341306e199844c244558307a055e0-1-Copy_jpg.rf.f67a82d6ac74bc06ea8bf3ca504c4237.jpg
# Removing: dataset/labels/t-lichen-simplex-chronicus-131_jpg.rf.5f052bfd70f9c1b08f78941b6bb61015.txt
# Removing: dataset/images/t-lichen-simplex-chronicus-131_jpg.rf.5f052bfd70f9c1b08f78941b6bb61015.jpg
# Removing: dataset/labels/viral-wart-06__WatermarkedWyJXYXRlcm1hcmtlZCJd-Copy_jpg.rf.189ef653a464bba6492d5071480d33ec.txt
# Removing: dataset/images/viral-wart-06__WatermarkedWyJXYXRlcm1hcmtlZCJd-Copy_jpg.rf
# Removing: dataset/images/7_35_jpg.rf.1dfa4245199546c7e11a2028af753daa.jpg
# Removing: dataset/labels/PSORT49_jpg.rf.d346d0c360b957ca2fbc38460e27526d.txt
# Removing: dataset/images/PSORT49_jpg.rf.d346d0c360b957ca2fbc38460e27526d.jpg
# Removing: dataset/labels/images-4-Copy_jpg.rf.e5096f1083d7f283acf28f2191b5d8ca.txt
# Removing: dataset/images/images-4-Copy_jpg.rf.e5096f1083d7f283acf28f2191b5d8ca.jpg
# Removing: dataset/labels/ring-worm-infection-dermatophytosis-skin-ringworm-infection-tinea-skin-mycosis-infection-human-skin-caused-160386579-Copy_jpg.rf.3c2fbafa80143d823477b3574832a101.txt
# Removing: dataset/images/ring-worm-infection-dermatophytosis-skin-ringworm-infection-tinea-skin-mycosis-infection-human-skin-caused-160386579-Copy_jpg.rf.3c2fbafa80143d823477b3574832a101.jpg
# Removing: dataset/labels/erythema-migrans93_jpg.rf.3e580c42af5ba6859065d695ddcf5bc6.txt
# Removing: dataset/images/erythema-migrans93_jpg.rf.3e580c42af5ba6859065d695ddcf5bc6.jpg
# Removing: dataset/labels/KP-5-_jpg.rf.22cbe7433ce3a2c881f24f7ba4341b57.txt
# Removing: dataset/images/KP-5-_jpg.rf.22cbe7433ce3a2c881f24f7ba4341b57.jpg
# Removing: dataset/labels/ringworm-on-neck-2-Copy_jpg.rf.04224753b64db2565fe5c336a94e4353.txt
# Removing: dataset/images/ringworm-on-neck-2-Copy_jpg.rf.04224753b64db2565fe5c336a94e4353.jpg
# Removing: dataset/labels/05KeratosisPilaris10131_jpeg_jpg.rf.029a3c43a25bd0c6cdb17e99670cbe0f.txt
# Removing: dataset/images/05KeratosisPilaris10131_jpeg_jpg.rf.029a3c43a25bd0c6cdb17e99670cbe0f.jpg
# Removing: dataset/labels/ringworm27_png_jpg.rf.040a18ff82329065f446f379a9593661.txt
# Removing: dataset/images/ringworm27_png_jpg.rf.040a18ff82329065f446f379a9593661.jpg
# Removing: dataset/labels/L-28-_jpg.rf.6790d7c2e6c051c8f0246eecded04f8d.txt
# Removing: dataset/images/L-28-_jpg.rf.6790d7c2e6c051c8f0246eecded04f8d.jpg
# Removing: dataset/labels/t-warts-3_jpg.rf.d78997312c8ecc5f43a1b05510b90906.txt
# Removing: dataset/images/t-warts-3_jpg.rf.d78997312c8ecc5f43a1b05510b90906.jpg
# Removing: dataset/labels/t-phlebitis-superficial-3_jpg.rf.e535c635ae3614c415a07ad54c3fc193.txt
# Removing: dataset/images/t-phlebitis-superficial-3_jpg.rf.e535c635ae3614c415a07ad54c3fc193.jpg
# Removing: dataset/labels/R-30-Copy_jpg.rf.48c4e59a35f1445a0e4684803961e879.txt
# Removing: dataset/images/R-30-Copy_jpg.rf.48c4e59a35f1445a0e4684803961e879.jpg
# Removing: dataset/labels/g_PNG_jpg.rf.5b4f80a35aa25570bb2c0d7cda650dbd.txt
# Removing: dataset/images/g_PNG_jpg.rf.5b4f80a35aa25570bb2c0d7cda650dbd.jpg
# Removing: dataset/images/PSORT195_jpg.rf.8f113e0e24d316a7d8851da31e5a9268.jpg
# Removing: dataset/labels/7_jpg.rf.831d59623663c7e754e72f9fd8312b7f.txt
# Removing: dataset/images/7_jpg.rf.831d59623663c7e754e72f9fd8312b7f.jpg
# Removing: dataset/labels/Pityriasis-rosea-rash99_png_jpg.rf.3b80a0e3831d7f8a79f8b73aaca25c2d.txt
# Removing: dataset/images/Pityriasis-rosea-rash99_png_jpg.rf.3b80a0e3831d7f8a79f8b73aaca25c2d.jpg
# Removing: dataset/labels/wart14__WatermarkedWyJXYXRlcm1hcmtlZCJd-Copy_jpg.rf.721d3a77c9dbf5d9aeccde05a45fc535.txt
# Removing: dataset/images/wart14__WatermarkedWyJXYXRlcm1hcmtlZCJd-Copy_jpg.rf.721d3a77c9dbf5d9aeccde05a45fc535.jpg
# Removing: dataset/labels/sdf_PNG_jpg.rf.3a1278cf9422dd2fadb7c2717e24ad9b.txt
# Removing: dataset/images/sdf_PNG_jpg.rf.3a1278cf9422dd2fadb7c2717e24ad9b.jpg
# Removing: dataset/labels/erythema-migrans123_jpg.rf.c7f026900206cc36095dd8933d80d42a.txt
# Removing: dataset/images/erythema-migrans123_jpg.rf.c7f026900206cc36095dd8933d80d42a.jpg
# Removing: dataset/labels/7_40_jpg.rf.58882bf26257ebb96747b0744fe90f0d.txt
# Removing: dataset/images/7_40_jpg.rf.58882bf26257ebb96747b0744fe90f0d.jpg
# Removing: dataset/labels/pigmentation_0_2298-Copy_jpeg_jpg.rf.f8e2f134aac63676613a3c3328f63c9a.txt
# Removing: dataset/images/pigmentation_0_2298-Copy_jpeg_jpg.rf.f8e2f134aac63676613a3c3328f63c9a.jpg
# Removing: dataset/labels/t-lichen-simplex-chronicus-130_jpg.rf.afb462294a104ac0067135bc199b7ad1.txt
# Removing: dataset/images/t-lichen-simplex-chronicus-130_jpg.rf.afb462294a104ac0067135bc199b7ad1.jpg
# Removing: dataset/labels/648x364_Ringworm_Body_Tinea_Corporis-Copy_jpg.rf.c56da83b7b4c10af8102ff9d00891a93.txt
# Removing: dataset/images/648x364_Ringworm_Body_Tinea_Corporis-Copy_jpg.rf.c56da83b7b4c10af8102ff9d00891a93.jpg
# Removing: dataset/labels/erythema-migrans156_png_jpg.rf.f5efebf2fa18300f1ca2561a054b1041.txt
# Removing: dataset/images/erythema-migrans156_png_jpg.rf.f5efebf2fa18300f1ca2561a054b1041.jpg
# Removing: dataset/labels/v-lichen-simplex-chronicus-19_jpg.rf.3151d6ef709b0c7e92ef3960061031a3.txt
# Removing: dataset/images/v-lichen-simplex-chronicus-19_jpg.rf.3151d6ef709b0c7e92ef3960061031a3.jpg
# Removing: dataset/labels/LD-17-_jpg.rf.06a174c51161cf993b730f82e6ce8275.txt
# Removing: dataset/images/LD-17-_jpg.rf.06a174c51161cf993b730f82e6ce8275.jpg
# Removing: dataset/labels/KP-9-_jpg.rf.abe7640fa1faf28e00f173c9216dc741.txt
# Removing: dataset/images/KP-9-_jpg.rf.abe7640fa1faf28e00f173c9216dc741.jpg
# Removing: dataset/labels/acne-vulgaris-pictures-61-Copy_jpg.rf.5bad361059ca61553e4a02809b83d987.txt
# Removing: dataset/images/acne-vulgaris-pictures-61-Copy_jpg.rf.5bad361059ca61553e4a02809b83d987.jpg
# Removing: dataset/labels/LD-26-_jpg.rf.08c79beeb32e17725e3fd89b45261d4d.txt
# Removing: dataset/images/LD-26-_jpg.rf.08c79beeb32e17725e3fd89b45261d4d.jpg
# Removing: dataset/labels/L-31-_jpg.rf.0dbd9dd76c78a4234f8b8d9a0d563eb1.txt
# Removing: dataset/images/L-31-_jpg.rf.0dbd9dd76c78a4234f8b8d9a0d563eb1.jpg
# Removing: dataset/labels/LD-12-_jpg.rf.561b2d9d975b563ee010c8bb46bf511b.txt
# Removing: dataset/images/LD-12-_jpg.rf.561b2d9d975b563ee010c8bb46bf511b.jpg
# Removing: dataset/labels/cystic-acne_G_694069050-Copy_jpg.rf.6358ffa6a9179db007fe019f82482c3b.txt
# Removing: dataset/images/cystic-acne_G_694069050-Copy_jpg.rf.6358ffa6a9179db007fe019f82482c3b.jpg
# Removing: dataset/labels/ringworm-56-_png_jpg.rf.64bfbc7295bdc073013970f8a6a684e8.txt
# Removing: dataset/images/ringworm-56-_png_jpg.rf.64bfbc7295bdc073013970f8a6a684e8.jpg
# Removing: dataset/labels/KP-30-_jpg.rf.a65a1ffc3e9660211d7f09325397804e.txt
# Removing: dataset/images/KP-30-_jpg.rf.a65a1ffc3e9660211d7f09325397804e.jpg
# Removing: dataset/labels/7_43-Copy_jpg.rf.daa945e104ce9d96741c5e44e552df67.txt
# Removing: dataset/images/7_43-Copy_jpg.rf.daa945e104ce9d96741c5e44e552df67.jpg
# Removing: dataset/labels/dsf_PNG_jpg.rf.c9f2fb2d016a3468ffbd9422834a743b.txt
# Removing: dataset/images/dsf_PNG_jpg.rf.c9f2fb2d016a3468ffbd9422834a743b.jpg
# Removing: dataset/labels/ringworm-skin-infection-symptoms-Copy_png_jpg.rf.bdffe0cfad986e9c5c31e2e23d60b352.txt
# Removing: dataset/images/ringworm-skin-infection-symptoms-Copy_png_jpg.rf.bdffe0cfad986e9c5c31e2e23d60b352.jpg
# Removing: dataset/labels/plantar-warts-5-1200x984-Copy_jpg.rf.a5c9601f224816e22c309cfe1c99e2ce.txt
# Removing: dataset/images/plantar-warts-5-1200x984-Copy_jpg.rf.a5c9601f224816e22c309cfe1c99e2ce.jpg
# Removing: dataset/labels/KPD-7-_jpg.rf.48a487c2f88d27a0e0112cfaaba6cf34.txt
# Removing: dataset/images/KPD-7-_jpg.rf.48a487c2f88d27a0e0112cfaaba6cf34.jpg
# Removing: dataset/labels/t-warts-plantar-43_jpg.rf.47e02b551910e32c9e2afef981126406.txt
# Removing: dataset/images/t-warts-plantar-43_jpg.rf.47e02b551910e32c9e2afef981126406.jpg
# Removing: dataset/labels/3_4_jpg.rf.3dcaf70c20fb854fea0094b9adad2d62.txt
# Removing: dataset/images/3_4_jpg.rf.3dcaf70c20fb854fea0094b9adad2d62.jpg
# Removing: dataset/labels/LD-12-_jpg.rf.2878aca95c46d9f6829d96bd19f2f2fe.txt
# Removing: dataset/images/LD-12-_jpg.rf.2878aca95c46d9f6829d96bd19f2f2fe.jpg
# Removing: dataset/labels/LD-26-_jpg.rf.81e5943d5975ae5c776eddd7e0f4a030.txt
# Removing: dataset/images/LD-26-_jpg.rf.81e5943d5975ae5c776eddd7e0f4a030.jpg
# Removing: dataset/labels/ringworm-33-_png_jpg.rf.2a0efb55968547057aee7157c5d80f09.txt
# Removing: dataset/images/ringworm-33-_png_jpg.rf.2a0efb55968547057aee7157c5d80f09.jpg
# Removing: dataset/labels/Leprosy_210823_152_jpg.rf.f513565c30e2f5efc91f15fee6818212.txt
# Removing: dataset/images/Leprosy_210823_152_jpg.rf.f513565c30e2f5efc91f15fee6818212.jpg
# Removing: dataset/labels/acne-Copy_jpg.rf.0f35f9e08e8c1a7474070f8351680f57.txt
# Removing: dataset/images/acne-Copy_jpg.rf.0f35f9e08e8c1a7474070f8351680f57.jpg
# Removing: dataset/labels/L-11-_jpg.rf.5daf88e1a6d8e0c92d630cea7021e0f4.txt
# Removing: dataset/images/L-11-_jpg.rf.5daf88e1a6d8e0c92d630cea7021e0f4.jpg
# Removing: dataset/labels/61-Keratosis_jpg.rf.67e497a26f34d39ca4f66a952de46b3f.txt
# Removing: dataset/images/61-Keratosis_jpg.rf.67e497a26f34d39ca4f66a952de46b3f.jpg
# Removing: dataset/labels/LD-3-_jpg.rf.b8afa14ebc87ea7f65924a38c2c036ce.txt
# Removing: dataset/images/LD-3-_jpg.rf.b8afa14ebc87ea7f65924a38c2c036ce.jpg
# Removing: dataset/labels/17758-keratosis-pilaris-1332694298_jpg.rf.a774e2387d70d2340f140ea024641e8d.txt
# Removing: dataset/images/17758-keratosis-pilaris-1332694298_jpg.rf.a774e2387d70d2340f140ea024641e8d.jpg
# Removing: dataset/labels/images-1-Copy_jpg.rf.cffcedc93f18905478bdbc8c14db8255.txt
# Removing: dataset/images/images-1-Copy_jpg.rf.cffcedc93f18905478bdbc8c14db8255.jpg
# Removing: dataset/labels/ringworm49_png_jpg.rf.1919312bfb70d4737c804e07bb732ed2.txt
# Removing: dataset/images/ringworm49_png_jpg.rf.1919312bfb70d4737c804e07bb732ed2.jpg
# Removing: dataset/labels/ring-worm-infection-dermatophytosis-skin-ringworm-infection-tinea-skin-mycosis-infection-human-skin-caused-160386579-Copy_jpg.rf.b65c23d9e09bfe354dae45f74b5be1aa.txt
# Removing: dataset/images/ring-worm-infection-dermatophytosis-skin-ringworm-infection-tinea-skin-mycosis-infection-human-skin-caused-160386579-Copy_jpg.rf.b65c23d9e09bfe354dae45f74b5be1aa.jpg
# Removing: dataset/labels/Captures_PNG_jpg.rf.078196bbcdb00c2b89f1b593e725900e.txt
# Removing: dataset/images/Captures_PNG_jpg.rf.078196bbcdb00c2b89f1b593e725900e.jpg
# Removing: dataset/labels/3017__WatermarkedWyJXYXRlcm1hcmtlZCJd_jpg.rf
# Removing: dataset/images/pigmentation_0_29-Copy_jpeg_jpg.rf.1feffd78029b8564d8ad7850df885377.jpg
# Removing: dataset/labels/images-5-Copy_jpg.rf.67ba79336e163293a317d1989082aa75.txt
# Removing: dataset/images/images-5-Copy_jpg.rf.67ba79336e163293a317d1989082aa75.jpg
# Removing: dataset/labels/8_5_jpg.rf.08784a73a25ffad936e0d1eac5bdaf38.txt
# Removing: dataset/images/8_5_jpg.rf.08784a73a25ffad936e0d1eac5bdaf38.jpg
# Removing: dataset/labels/verruca__WatermarkedWyJXYXRlcm1hcmtlZCJd-1-Copy_jpg.rf.ada82f4d0c05677212a495a706eb5138.txt
# Removing: dataset/images/verruca__WatermarkedWyJXYXRlcm1hcmtlZCJd-1-Copy_jpg.rf.ada82f4d0c05677212a495a706eb5138.jpg
# Removing: dataset/labels/LD-28-_jpg.rf.fdba298c6fbc84c74b0fad5eb84af898.txt
# Removing: dataset/images/LD-28-_jpg.rf.fdba298c6fbc84c74b0fad5eb84af898.jpg
# Removing: dataset/labels/t-warts-common-112_jpg.rf.95549fe63f60270035e477c904b993be.txt
# Removing: dataset/images/t-warts-common-112_jpg.rf.95549fe63f60270035e477c904b993be.jpg
# Removing: dataset/labels/erythema-migrans280_png_jpg.rf.6360a87b8117ae2d7bb47556b5a046a7.txt
# Removing: dataset/images/erythema-migrans280_png_jpg.rf.6360a87b8117ae2d7bb47556b5a046a7.jpg
# Removing: dataset/labels/L-30-_jpg.rf.9312e99986f885095377c2ea58a95170.txt
# Removing: dataset/images/L-30-_jpg.rf.9312e99986f885095377c2ea58a95170.jpg
# Removing: dataset/labels/t-warts-common-39_jpg.rf.1a07d4b180ef0da6e2c468b37e60a919.txt
# Removing: dataset/images/t-warts-common-39_jpg.rf.1a07d4b180ef0da6e2c468b37e60a919.jpg
# Removing: dataset/labels/PSORT127_JPG_jpg.rf.90c82b47839a24963fc4bb650f811adb.txt
# Removing: dataset/images/PSORT127_JPG_jpg.rf.90c82b47839a24963fc4bb650f811adb.jpg
# Removing: dataset/labels/Leprosy_-_210823_0_jpg.rf.3cddad135c41d8e272a6e5395ccdaba5.txt
# Removing: dataset/images/Leprosy_-_210823_0_jpg.rf.3cddad135c41d8e272a6e5395ccdaba5.jpg
# Removing: dataset/labels/erythema-migrans241_png_jpg.rf.a0eb969204c0587b8e653542d628ceec.txt
# Removing: dataset/images/erythema-migrans241_png_jpg.rf.a0eb969204c0587b8e653542d628ceec.jpg
# Removing: dataset/labels/KP-7-_jpg.rf.183ee6a1471e1462ad1405cbdd13c1b3.txt
# Removing: dataset/images/KP-7-_jpg.rf.183ee6a1471e1462ad1405cbdd13c1b3.jpg
# Removing: dataset/labels/ringworm48_png_jpg.rf.b4acc63009ce4151a362c12b3164887a.txt
# Removing: dataset/images/ringworm48_png_jpg.rf.b4acc63009ce4151a362c12b3164887a.jpg
# Removing: dataset/labels/viral-wart-16__WatermarkedWyJXYXRlcm1hcmtlZCJd-Copy_jpg.rf.9e0164aa84c443fae8f10db323d2a911.txt
# Removing: dataset/images/viral-wart-16__WatermarkedWyJXYXRlcm1hcmtlZCJd-Copy_jpg.rf.9e0164aa84c443fae8f10db323d2a911.jpg
# Removing: dataset/labels/sjs-ten-oral-0__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd_jpg.rf.fbf4c79ba7f25cc6ac3ee009f4156f53.txt
# Removing: dataset/images/sjs-ten-oral-0__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd_jpg.rf.fbf4c79ba7f25cc6ac3ee009f4156f53.jpg
# Removing: dataset/labels/08psoriasisIntertrig020606_jpg.rf.a3ddbfa955f860fed7f382529bc0ec30.txt
# Removing: dataset/images/08psoriasisIntertrig020606_jpg.rf.a3ddbfa955f860fed7f382529bc0ec30.jpg
# Removing: dataset/labels/q_PNG_jpg.rf.3663688dc809c1a28dab88a91a2bcebc.txt
# Removing: dataset/images/q_PNG_jpg.rf.3663688dc809c1a28dab88a91a2bcebc.jpg
# Removing: dataset/labels/image20_jpeg_jpg.rf.670f2597e2deda5022f33e3d7917a31d.txt
# Removing: dataset/images/image20_jpeg_jpg.rf.670f2597e2deda5022f33e3d7917a31d.jpg
# Removing: dataset/labels/4_9_jpg.rf.208505b99924769fbe0d35b9f6cf61ee.txt
# Removing: dataset/images/4_9_jpg.rf.208505b99924769fbe0d35b9f6cf61ee.jpg
# Removing: dataset/labels/Leprosy_190463_210823_0_jpg.rf.c4fcea02e4e12ae88640253e6cc253ae.txt
# Removing: dataset/images/Leprosy_190463_210823_0_jpg.rf.c4fcea02e4e12ae88640253e6cc253ae.jpg
# Removing: dataset/labels/Leprosy-26_jpg.rf.822535c169b30d1cdff65b544f5d4884.txt
# Removing: dataset/images/Leprosy-26_jpg.rf.822535c169b30d1cdff65b544f5d4884.jpg
# Removing: dataset/labels/Leprosy-85_jpg.rf.9751ba3d155d280655cf9372f20c6fcb.txt
# Removing: dataset/images/Leprosy-85_jpg.rf.9751ba3d155d280655cf9372f20c6fcb.jpg
# Removing: dataset/labels/PSORT3_jpg.rf.60dcc975c7458c681943afaf4f0483b1.txt
# Removing: dataset/images/PSORT3_jpg.rf.60dcc975c7458c681943afaf4f0483b1.jpg
# Removing: dataset/labels/A-Z_ringworm-1_22012020-1-Copy_jpg.rf.ab552699f4f5cf79fdf9f52d4a141ed0.txt
# Removing: dataset/images/A-Z_ringworm-1_22012020-1-Copy_jpg.rf.ab552699f4f5cf79fdf9f52d4a141ed0.jpg
# Removing: dataset/labels/L-18-_jpg.rf.51bca638bb5806eba7c7be70d60fb6de.txt
# Removing: dataset/images/L-18-_jpg.rf.51bca638bb5806eba7c7be70d60fb6de.jpg
# Removing: dataset/labels/L-10-_jpg.rf.9c7013f4b65b219f42aa44c24a03e4e6.txt
# Removing: dataset/images/L-10-_jpg.rf.9c7013f4b65b219f42aa44c24a03e4e6.jpg
# Removing: dataset/labels/LD-9-_jpg.rf.7c9f741c5e0f45c93c59266d6fe789d6.txt
# Removing: dataset/images/LD-9-_jpg.rf.7c9f741c5e0f45c93c59266d6fe789d6.jpg
# Removing: dataset/labels/erythema-migrans30_png_jpg.rf.29c03ba555e905f62547407c79666a2f.txt
# Removing: dataset/images/erythema-migrans30_png_jpg.rf.29c03ba555e905f62547407c79666a2f.jpg
# Removing: dataset/labels/ask-a-dermatologist-keratosis-pilaris_png_jpg.rf.c9a8a668c77cc6002b82683c72136578.txt
# Removing: dataset/labels/t-warts-12_jpg.rf.1f2adda50f2e7efe84dd90e568b0aa3f.txt
# Removing: dataset/images/t-warts-12_jpg.rf.1f2adda50f2e7efe84dd90e568b0aa3f.jpg
# Removing: dataset/labels/t-warts-common-95_jpg.rf.db02f3f3737eead50ba9393a8bb994d9.txt
# Removing: dataset/images/t-warts-common-95_jpg.rf.db02f3f3737eead50ba9393a8bb994d9.jpg
# Removing: dataset/labels/t-warts-common-79_jpg.rf.d4d95f11938b2f2f960561704fc2e28b.txt
# Removing: dataset/images/t-warts-common-79_jpg.rf.d4d95f11938b2f2f960561704fc2e28b.jpg
# Removing: dataset/labels/7_44_jpg.rf.371101cde2053a2063963b8e41bc97ec.txt
# Removing: dataset/images/7_44_jpg.rf.371101cde2053a2063963b8e41bc97ec.jpg
# Removing: dataset/labels/KP-37-_jpg.rf.5f40260a44fe302e417ce5471d10d2d8.txt
# Removing: dataset/images/KP-37-_jpg.rf.5f40260a44fe302e417ce5471d10d2d8.jpg
# Removing: dataset/labels/viral-wart-11__WatermarkedWyJXYXRlcm1hcmtlZCJd-Copy_jpg.rf.4df46dade13615ea30b69bb2c77a4dd3.txt
# Removing: dataset/images/viral-wart-11__WatermarkedWyJXYXRlcm1hcmtlZCJd-Copy_jpg.rf.4df46dade13615ea30b69bb2c77a4dd3.jpg
# Removing: dataset/labels/4_17_jpg.rf.73dac0206c44bc7fb406470b287565d2.txt
# Removing: dataset/images/4_17_jpg.rf.73dac0206c44bc7fb406470b287565d2.jpg
# Removing: dataset/labels/images-88-_jpeg_jpg.rf.de879ad91c36cbe8bd1b004524a63246.txt
# Removing: dataset/images/images-88-_jpeg_jpg.rf.de879ad91c36cbe8bd1b004524a63246.jpg
# Removing: dataset/labels/KPD-12-_jpg.rf.4fa55cfc2053397632808852363eaff2.txt
# Removing: dataset/images/KPD-12-_jpg.rf.4fa55cfc2053397632808852363eaff2.jpg
# Removing: dataset/labels/fixed-drug-reaction32_png_jpg.rf.63904c9ce8c9a41645be452281a1c1bb.txt
# Removing: dataset/images/fixed-drug-reaction32_png_jpg.rf.63904c9ce8c9a41645be452281a1c1bb.jpg
# Removing: dataset/labels/t-lichen-simplex-chronicus-131_jpg.rf.72092d9ff201be5652550a8bd5f71623.txt
# Removing: dataset/images/t-lichen-simplex-chronicus-131_jpg.rf.72092d9ff201be5652550a8bd5f71623.jpg
# Removing: dataset/labels/maxresdefault-2-Copy_jpg.rf.911170a61252a6584629f0a868716620.txt
# Removing: dataset/images/maxresdefault-2-Copy_jpg.rf.911170a61252a6584629f0a868716620.jpg
# Removing: dataset/labels/Filliform-Wart-20140911092652619-Copy_jpg.rf.5256254f4b192715a2215bdc3f23406c.txt
# Removing: dataset/images/Filliform-Wart-20140911092652619-Copy_jpg.rf.5256254f4b192715a2215bdc3f23406c.jpg
# Removing: dataset/labels/erythema-migrans30_png_jpg.rf.f1e01d38b2efa8ebe09e420eb0cd3c9d.txt
# Removing: dataset/images/erythema-migrans30_png_jpg.rf.f1e01d38b2efa8ebe09e420eb0cd3c9d.jpg
# Removing: dataset/labels/how-to-get-rid-of-acne-and-its-possible-treatments-Copy_jpg.rf.e76f954758a7f392cb0bc36832bd4683.txt
# Removing: dataset/images/how-to-get-rid-of-acne-and-its-possible-treatments-Copy_jpg.rf.e76f954758a7f392cb0bc36832bd4683.jpg
# Removing: dataset/labels/t-heels-dry-cracked-8_jpg.rf.a24dd89143541b5a2ab04abf6290fe11.txt
# Removing: dataset/images/t-heels-dry-cracked-8_jpg.rf.a24dd89143541b5a2ab04abf6290fe11.jpg
# Removing: dataset/labels/princ_sm4397_129125-Copy_jpg.rf.a5b3ddacbc7369af53ae57c26e859d99.txt
# Removing: dataset/images/princ_sm4397_129125-Copy_jpg.rf.a5b3ddacbc7369af53ae57c26e859d99.jpg
# Removing: dataset/labels/KP-10-_jpg.rf.5ef7700ee60409f292942dad1b13e655.txt
# Removing: dataset/images/KP-10-_jpg.rf.5ef7700ee60409f292942dad1b13e655.jpg
# Removing: dataset/labels/DvJyeM8W0AALvXc-Copy_jpg.rf.3b54832fe438607f7d04e2fc46d3f3cf.txt
# Removing: dataset/images/DvJyeM8W0AALvXc-Copy_jpg.rf.3b54832fe438607f7d04e2fc46d3f3cf.jpg
# Removing: dataset/labels/1c4fd4cc-a697-480d-994a-9611fdb2bc3e-1-Copy_jpg.rf.619cea5452531d3e06244ec371944b4d.txt
# Removing: dataset/images/1c4fd4cc-a697-480d-994a-9611fdb2bc3e-1-Copy_jpg.rf.619cea5452531d3e06244ec371944b4d.jpg
# Removing: dataset/labels/Keratosis_Pilaris_on_Lower_Extremity_600x600_jpg.rf.73f3ce6f85703740632efe214484fae8.txt
# Removing: dataset/images/Keratosis_Pilaris_on_Lower_Extremity_600x600_jpg.rf.73f3ce6f85703740632efe214484fae8.jpg
# Removing: dataset/labels/what-does-keratosis-pilaris-look-like-treatments-available-kansas-city-dermatology-1024x768_jpg.rf.629378d11f4766c33dc631ffe9807dea.txt
# Removing: dataset/images/what-does-keratosis-pilaris-look-like-treatments-available-kansas-city-dermatology-1024x768_jpg.rf.629378d11f4766c33dc631ffe9807dea.jpg
# Removing: dataset/labels/R-7-Copy_jpg.rf.e9da776ea3081853d7cdc5dfb74e80af.txt
# Removing: dataset/images/R-7-Copy_jpg.rf.e9da776ea3081853d7cdc5dfb74e80af.jpg
# Removing: dataset/labels/KP-25-_jpg.rf.02a46f5dbeedc297de805897b160bc5e.txt
# Removing: dataset/images/KP-25-_jpg.rf.02a46f5dbeedc297de805897b160bc5e.jpg
# Removing: dataset/labels/LD-29-_jpg.rf.90c4472bd0586373fac4b33d57ae009f.txt
# Removing: dataset/images/LD-29-_jpg.rf.90c4472bd0586373fac4b33d57ae009f.jpg
# Removing: dataset/labels/KP-16-_jpg.rf.f8fc5d37f7a19b753b6b905d66bf253e.txt
# Removing: dataset/images/KP-16-_jpg.rf.f8fc5d37f7a19b753b6b905d66bf253e.jpg
# Removing: dataset/labels/erythema-migrans54_png_jpg.rf.6cd481ad9957d990f0de69e1ab23d62e.txt
# Removing: dataset/images/erythema-migrans54_png_jpg.rf.6cd481ad9957d990f0de69e1ab23d62e.jpg
# Removing: dataset/labels/wart18__WatermarkedWyJXYXRlcm1hcmtlZCJd-Copy_jpg.rf
# Removing: dataset/labels/KP-9-_jpg.rf.efb7c6f6e7dd25ca3625b7f59838f85c.txt
# Removing: dataset/images/KP-9-_jpg.rf.efb7c6f6e7dd25ca3625b7f59838f85c.jpg
# Removing: dataset/labels/KPD-11-_jpg.rf.9a94a176f59dc6f063ea636575ecee3a.txt
# Removing: dataset/images/KPD-11-_jpg.rf.9a94a176f59dc6f063ea636575ecee3a.jpg
# Removing: dataset/labels/Cutaneous-viral-wart-showing-characteristic-hyperkeratotic-warty-surface-with-1-Copy_png_jpg.rf.e0fb519f916d5baa091fbb05473fc89e.txt
# Removing: dataset/images/Cutaneous-viral-wart-showing-characteristic-hyperkeratotic-warty-surface-with-1-Copy_png_jpg.rf.e0fb519f916d5baa091fbb05473fc89e.jpg
# Removing: dataset/labels/Pityriasis-rosea-rash99_png_jpg.rf.46fcb53f39f88844c72c9d5255874d44.txt
# Removing: dataset/images/Pityriasis-rosea-rash99_png_jpg.rf.46fcb53f39f88844c72c9d5255874d44.jpg
# Removing: dataset/labels/Ringworm-jpg-Copy_jpg.rf.0043f63a4e3dca5ce069207af8dfd32a.txt
# Removing: dataset/images/Ringworm-jpg-Copy_jpg.rf.0043f63a4e3dca5ce069207af8dfd32a.jpg
# Removing: dataset/labels/LD-31-_jpg.rf.b84c53f55a9bc389f1063505ca384bce.txt
# Removing: dataset/images/LD-31-_jpg.rf.b84c53f55a9bc389f1063505ca384bce.jpg
# Removing: dataset/labels/images-12-Copy_jpg.rf.9e77bced58d37f71cefdc6d50687d554.txt
# Removing: dataset/images/images-12-Copy_jpg.rf.9e77bced58d37f71cefdc6d50687d554.jpg
# Removing: dataset/labels/QmxvZy0xNDAxNg-Copy_jpg.rf.76924280b06bacc26df44c7dca8ff846.txt
# Removing: dataset/images/QmxvZy0xNDAxNg-Copy_jpg.rf.76924280b06bacc26df44c7dca8ff846.jpg
# Removing: dataset/labels/ringworm_close-up_334x237-Copy_jpg.rf.7f1e4ae5169e117e10d459cc930a6cad.txt
# Removing: dataset/images/ringworm_close-up_334x237-Copy_jpg.rf.7f1e4ae5169e117e10d459cc930a6cad.jpg
# Removing: dataset/labels/warts1-e1557564557451-Copy_jpg.rf.7f974663961fc3ed215be9c4e7709c84.txt
# Removing: dataset/images/warts1-e1557564557451-Copy_jpg.rf.7f974663961fc3ed215be9c4e7709c84.jpg
# Removing: dataset/labels/L-21-_jpg.rf.89d3e5376b33c62d33148af3abf6677b.txt
# Removing: dataset/images/L-21-_jpg.rf.89d3e5376b33c62d33148af3abf6677b.jpg
# Removing: dataset/labels/KP-39-_jpg.rf.e5150621d4c7b8cb409ed3ae4c824a33.txt
# Removing: dataset/images/KP-39-_jpg.rf.e5150621d4c7b8cb409ed3ae4c824a33.jpg
# Removing: dataset/labels/t-eczema-asteatotic-15_jpg.rf.266681e6d55cb20a69b0536325dd1a30.txt
# ...
# Removing: dataset/labels/PSORT96_jpg.rf.bba463996cbc4ed94423738d65195e79.txt
# Removing: dataset/images/PSORT96_jpg.rf.bba463996cbc4ed94423738d65195e79.jpg
# Removing: dataset/labels/w_PNG_jpg.rf.1eacd4fe994a92bb51eb835c894ca0dc.txt
# Removing: dataset/images/w_PNG_jpg.rf.1eacd4fe994a92bb51eb835c894ca0dc.jpg
# Removing: dataset/labels/keratosis-pilaris-dinulos-sized_jpg.rf.d130e67fa0270f32a7c23c0e386d4a12.txt
# Removing: dataset/images/keratosis-pilaris-dinulos-sized_jpg.rf.d130e67fa0270f32a7c23c0e386d4a12.jpg
# Removing: dataset/labels/KP-39-_jpg.rf.f62445e562ef25b633e6231b5af3e703.txt
# Removing: dataset/images/KP-39-_jpg.rf.f62445e562ef25b633e6231b5af3e703.jpg
# Removing: dataset/labels/keratosis_pilaris_jpg.rf.446b1a334a6c341da1a834035cc03fc7.txt
# Removing: dataset/images/keratosis_pilaris_jpg.rf.446b1a334a6c341da1a834035cc03fc7.jpg
# Removing: dataset/labels/erythema-migrans93_jpg.rf.2e6ca36c8d0bee837e9f746f3237b5ab.txt
# Removing: dataset/images/erythema-migrans93_jpg.rf.2e6ca36c8d0bee837e9f746f3237b5ab.jpg
# Removing: dataset/labels/PSORT154_jpg.rf.4c6da529611fec4836314f42ba26799a.txt
# Removing: dataset/images/PSORT154_jpg.rf.4c6da529611fec4836314f42ba26799a.jpg
# Removing: dataset/labels/t-warts-40_jpg.rf.ea2bfddd1880a3626eeb3bcd3092761a.txt
# Removing: dataset/images/t-warts-40_jpg.rf.ea2bfddd1880a3626eeb3bcd3092761a.jpg
# Removing: dataset/labels/treating-chicken-skin-bumps-keratosis-pilaris_jpg.rf.60cea8614bed1784adcca190ad70845d.txt
# Removing: dataset/images/treating-chicken-skin-bumps-keratosis-pilaris_jpg.rf.60cea8614bed1784adcca190ad70845d.jpg
# Removing: dataset/labels/ringworm69_png_jpg.rf.e6ef43c21350aff2df7ce6a71a771439.txt
# Removing: dataset/images/ringworm69_png_jpg.rf.e6ef43c21350aff2df7ce6a71a771439.jpg
# Removing: dataset/labels/ringworm46_png_jpg.rf.646a2ec32be2aca6e4206135a70fbe76.txt
# Removing: dataset/images/ringworm46_png_jpg.rf.646a2ec32be2aca6e4206135a70fbe76.jpg
# Removing: dataset/labels/L-15-_jpg.rf.9a5d60cb69393af5961674ffcbe4f145.txt
# Removing: dataset/images/L-15-_jpg.rf.9a5d60cb69393af5961674ffcbe4f145.jpg
# Removing: dataset/labels/PSORT176_jpg.rf.745a309d7e51adf1fc7eb04a4d764930.txt
# Removing: dataset/images/PSORT176_jpg.rf.745a309d7e51adf1fc7eb04a4d764930.jpg
# Removing: dataset/labels/Capture_PNG_jpg.rf.f28fd1117d263e154e673f985066339f.txt
# Removing: dataset/images/Capture_PNG_jpg.rf.f28fd1117d263e154e673f985066339f.jpg
# Removing: dataset/labels/KP-5-_jpg.rf.098054c0fd2457bec19151144600d95a.txt
# Removing: dataset/images/KP-5-_jpg.rf.098054c0fd2457bec19151144600d95a.jpg
# Removing: dataset/labels/iStock-507545471_jpg.rf.d11f23055e07dc85e37cc73fc6aa4789.txt
# Removing: dataset/images/iStock-507545471_jpg.rf.d11f23055e07dc85e37cc73fc6aa4789.jpg
# Removing: dataset/labels/ringworm_4x3-Copy_jpg.rf.0e6574ba4c04f5aaf005057cd2f66cc1.txt
# Removing: dataset/images/ringworm_4x3-Copy_jpg.rf.0e6574ba4c04f5aaf005057cd2f66cc1.jpg
# Removing: dataset/labels/KP-43-_jpg.rf.39890977cb0c3f12c45f94d88f450e95.txt
# Removing: dataset/images/KP-43-_jpg.rf.39890977cb0c3f12c45f94d88f450e95.jpg
# Removing: dataset/labels/tagltjjrmelzgyxzo0bi_jpg.rf.850889134f306f89ad5c90e560723e79.txt
# Removing: dataset/images/tagltjjrmelzgyxzo0bi_jpg.rf.850889134f306f89ad5c90e560723e79.jpg
# Removing: dataset/labels/L-37-_jpg.rf.2d744d245348506fe98e7248be206dd0.txt
# Removing: dataset/images/L-37-_jpg.rf.2d744d245348506fe98e7248be206dd0.jpg
# Removing: dataset/labels/2979-Keratosis_Pilaris-1296x728-slide2-1_jpg.rf.d84ad22bc160bed3a3229b26711dadd0.txt
# Removing: dataset/images/2979-Keratosis_Pilaris-1296x728-slide2-1_jpg.rf.d84ad22bc160bed3a3229b26711dadd0.jpg
# Removing: dataset/labels/g_PNG_jpg.rf.aed4c5e2abf743d7b715df13b80ff569.txt
# Removing: dataset/images/g_PNG_jpg.rf.aed4c5e2abf743d7b715df13b80ff569.jpg
# Removing: dataset/labels/t-warts-common-113_jpg.rf.ac2188718ff5ceb956bb4da213cbf9ee.txt
# Removing: dataset/images/t-warts-common-113_jpg.rf.ac2188718ff5ceb956bb4da213cbf9ee.jpg
# Removing: dataset/labels/r120p0-Copy_jpg.rf.c9f6bf70a8821a0810a617b2a6d2f665.txt
# Removing: dataset/images/r120p0-Copy_jpg.rf.c9f6bf70a8821a0810a617b2a6d2f665.jpg
# Removing: dataset/labels/sjs-ten-face-31__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDg1XQ_jpg.rf.dbeb9e9136c84227b3b6e81e01931ea6.txt
# Removing: dataset/images/sjs-ten-face-31__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDg1XQ_jpg.rf.dbeb9e9136c84227b3b6e81e01931ea6.jpg
# Removing: dataset/labels/3022__WatermarkedWyJXYXRlcm1hcmtlZCJd-1-_jpg.rf.1ab248ff00c2ff8dba2d4effa28033b8.txt
# Removing: dataset/images/3022__WatermarkedWyJXYXRlcm1hcmtlZCJd-1-_jpg.rf.1ab248ff00c2ff8dba2d4effa28033b8.jpg
# Removing: dataset/labels/Leprosy150963_210823_54_jpg.rf.3fc0131e3a7b81903a90bfce74134938.txt
# Removing: dataset/images/Leprosy150963_210823_54_jpg.rf.3fc0131e3a7b81903a90bfce74134938.jpg
# Removing: dataset/labels/KP-36-_jpg.rf.3ecb4e982517477af2aed726f9703171.txt
# Removing: dataset/images/KP-36-_jpg.rf.3ecb4e982517477af2aed726f9703171.jpg
# Removing: dataset/labels/A-Z_ringworm-1_22012020-1-Copy_jpg.rf.dc017895909de81d73daa3893e9e487e.txt
# Removing: dataset/images/A-Z_ringworm-1_22012020-1-Copy_jpg.rf.dc017895909de81d73daa3893e9e487e.jpg
# Removing: dataset/labels/pigmentation_0_2363-Copy_jpeg_jpg.rf.3119d65ac76f173285a61a4aa0f8b6d9.txt
# Removing: dataset/images/pigmentation_0_2363-Copy_jpeg_jpg.rf.3119d65ac76f173285a61a4aa0f8b6d9.jpg
# Removing: dataset/labels/7e7bc824b57675c0ccea09d48a46f038-Copy_jpg.rf.b3fcfeec5aeff4b0962611706fb74b91.txt
# Removing: dataset/images/7e7bc824b57675c0ccea09d48a46f038-Copy_jpg.rf.b3fcfeec5aeff4b0962611706fb74b91.jpg
# Removing: dataset/labels/247MedCare_Ringworm-Copy_jpg.rf.3c484864aadc6ce9ebd6e65076ece6dc.txt
# Removing: dataset/images/247MedCare_Ringworm-Copy_jpg.rf.3c484864aadc6ce9ebd6e65076ece6dc.jpg
# Removing: dataset/labels/pigmentation_0_2696-Copy_jpeg_jpg.rf.9791cfc26d6ec725d45830355d70fd2e.txt
# Removing: dataset/images/pigmentation_0_2696-Copy_jpeg_jpg.rf.9791cfc26d6ec725d45830355d70fd2e.jpg
# Removing: dataset/labels/KP-38-_jpg.rf.9de1515a3f5e26af54891be5214eca4a.txt
# Removing: dataset/images/KP-38-_jpg.rf.9de1515a3f5e26af54891be5214eca4a.jpg
# Removing: dataset/labels/Capture-Copy_PNG_jpg.rf.3bdebfe578da697ff2f183e09be1c1c6.txt
# Removing: dataset/images/Capture-Copy_PNG_jpg.rf.3bdebfe578da697ff2f183e09be1c1c6.jpg
# Removing: dataset/labels/7_10_jpg.rf.0253ae1b947e3d25c58c33a1f41f721e.txt
# Removing: dataset/images/7_10_jpg.rf.0253ae1b947e3d25c58c33a1f41f721e.jpg
# Removing: dataset/labels/KP-31-_jpg.rf.f1856bce5652331eeb8042ac8bdaa83e.txt
# Removing: dataset/images/KP-31-_jpg.rf.f1856bce5652331eeb8042ac8bdaa83e.jpg
# Removing: dataset/labels/6_157-Copy_jpg.rf.82ee92da3bc9b0d6477611b5f3fedde4.txt
# Removing: dataset/images/6_157-Copy_jpg.rf.82ee92da3bc9b0d6477611b5f3fedde4.jpg
# Removing: dataset/labels/ringworm-5-Copy_jpg.rf.70c15218bf847ad2991b581b0c1a5e75.txt
# Removing: dataset/images/ringworm-5-Copy_jpg.rf.70c15218bf847ad2991b581b0c1a5e75.jpg
# Removing: dataset/labels/a_PNG_jpg.rf.8884a79685e11818b776626d759b5cbe.txt
# Removing: dataset/images/a_PNG_jpg.rf.8884a79685e11818b776626d759b5cbe.jpg
# Removing: dataset/labels/4_17_jpg.rf.29b5cc7bdc7d8cd8e794bcb9b3a016b9.txt
# Removing: dataset/images/4_17_jpg.rf.29b5cc7bdc7d8cd8e794bcb9b3a016b9.jpg
# Removing: dataset/labels/0_11_jpg.rf.21984cc698ec25b0730dd31ebfc41517.txt
# Removing: dataset/images/0_11_jpg.rf.21984cc698ec25b0730dd31ebfc41517.jpg
# Removing: dataset/labels/LD-30-_jpg.rf.af77984e0737882efcb8e1f567de6bf8.txt
# Removing: dataset/images/LD-30-_jpg.rf.af77984e0737882efcb8e1f567de6bf8.jpg
# Removing: dataset/labels/23-Copy_jpg.rf.01fdbd9e8bfeeeae9103ba38ebbb922a.txt
# Removing: dataset/images/23-Copy_jpg.rf.01fdbd9e8bfeeeae9103ba38ebbb922a.jpg
# Removing: dataset/labels/NoniSoap2-1-Copy_jpg.rf.a0c4d3bde2ad70d58e54c66b58ea3027.txt
# Removing: dataset/images/NoniSoap2-1-Copy_jpg.rf.a0c4d3bde2ad70d58e54c66b58ea3027.jpg
# Removing: dataset/labels/KP-14-_jpg.rf.0e39e2c628003fb3444775422edeb8da.txt
# Removing: dataset/images/KP-14-_jpg.rf.0e39e2c628003fb3444775422edeb8da.jpg
# Removing: dataset/labels/16-Copy_jpg.rf.153e7048cde922c259ef29c4fc6ed7bf.txt
# Removing: dataset/images/16-Copy_jpg.rf.153e7048cde922c259ef29c4fc6ed7bf.jpg
# Removing: dataset/labels/PSORT23_jpg.rf.e9278f330245f082621f0dc892fedfde.txt
# Removing: dataset/images/PSORT23_jpg.rf.e9278f330245f082621f0dc892fedfde.jpg
# Removing: dataset/labels/KP-34-_jpg.rf.bcdbfd65abc907398b8b203aade29d69.txt
# Removing: dataset/images/KP-34-_jpg.rf.bcdbfd65abc907398b8b203aade29d69.jpg
# Removing: dataset/labels/KP-18-_jpg.rf.8bbb1e8cbcdcd045a9bd9416d3fb8fdf.txt
# Removing: dataset/images/KP-18-_jpg.rf.8bbb1e8cbcdcd045a9bd9416d3fb8fdf.jpg
# Removing: dataset/labels/OIP-15-Copy_jpg.rf.7589f7dc7072d7522e5674f419c44536.txt
# Removing: dataset/images/OIP-15-Copy_jpg.rf.7589f7dc7072d7522e5674f419c44536.jpg
# Removing: dataset/labels/jko16nvn14061-Copy_png_jpg.rf.dea2592c03b118cf0a0e0cd02c9559f1.txt
# Removing: dataset/images/jko16nvn14061-Copy_png_jpg.rf.dea2592c03b118cf0a0e0cd02c9559f1.jpg
# Removing: dataset/labels/t-tinea-body-2_jpg.rf.a376eb0f553c0b57e7a595b8e457b2a6.txt
# Removing: dataset/images/t-tinea-body-2_jpg.rf.a376eb0f553c0b57e7a595b8e457b2a6.jpg
# Removing: dataset/labels/t-warts-plantar-34_jpg.rf.20414aa92c3f18887d2e33a199840b1b.txt
# Removing: dataset/images/t-warts-plantar-34_jpg.rf.20414aa92c3f18887d2e33a199840b1b.jpg
# Removing: dataset/labels/PSORT81_JPG_jpg.rf.25a48b47f948b175b9f683e8381a02c0.txt
# Removing: dataset/images/PSORT81_JPG_jpg.rf.25a48b47f948b175b9f683e8381a02c0.jpg
# Removing: dataset/labels/t-lichen-simplex-chronicus-130_jpg.rf.23eb237bc34d215cc42f10aa980caab1.txt
# Removing: dataset/images/t-lichen-simplex-chronicus-130_jpg.rf.23eb237bc34d215cc42f10aa980caab1.jpg
# Removing: dataset/labels/PSORT27_JPG_jpg.rf.7dc3e8d3c9b4e2c42ab1038b1861b38b.txt
# Removing: dataset/images/PSORT27_JPG_jpg.rf.7dc3e8d3c9b4e2c42ab1038b1861b38b.jpg
# Removing: dataset/labels/ringworm-3-Copy_jpg.rf.f04238d97a4a6d2b1091621ca639c78f.txt
# Removing: dataset/labels/L-28-_jpg.rf.fb50c793d52c9357ad78601c3ff10fb6.txt
# Removing: dataset/images/L-28-_jpg.rf.fb50c793d52c9357ad78601c3ff10fb6.jpg
# Removing: dataset/labels/Psoriasis-Chronic-Plaque-168_jpg.rf.2b5cfaec3c6b9d6884aadc5559014278.txt
# Removing: dataset/images/Psoriasis-Chronic-Plaque-168_jpg.rf.2b5cfaec3c6b9d6884aadc5559014278.jpg
# Removing: dataset/labels/t-eczema-trunk-generalized-6_jpg.rf.d28b26426da28bfc258a168ba3afb74c.txt
# Removing: dataset/images/t-eczema-trunk-generalized-6_jpg.rf.d28b26426da28bfc258a168ba3afb74c.jpg
# Removing: dataset/labels/KP-27-_jpg.rf.83dd240996876f5a30c7614369fe3c59.txt
# Removing: dataset/images/KP-27-_jpg.rf.83dd240996876f5a30c7614369fe3c59.jpg
# Removing: dataset/labels/t-warts-common-100_jpg.rf.b40eddde29f96ce8dc57d38966d99593.txt
# Removing: dataset/images/t-warts-common-100_jpg.rf.b40eddde29f96ce8dc57d38966d99593.jpg
# Removing: dataset/labels/wart9__WatermarkedWyJXYXRlcm1hcmtlZCJd-Copy_jpg.rf.50837adcc42dbe4929a4c180752bc863.txt
# Removing: dataset/images/wart9__WatermarkedWyJXYXRlcm1hcmtlZCJd-Copy_jpg.rf.50837adcc42dbe4929a4c180752bc863.jpg
# Removing: dataset/labels/Warts-Copy_jpg.rf.59967e0ce808bb64b69731f9ff4f0cc3.txt
# Removing: dataset/images/Warts-Copy_jpg.rf.59967e0ce808bb64b69731f9ff4f0cc3.jpg
# Removing: dataset/labels/ringworn-skin-Copy_jpg.rf.5e75e54588b702604fedb3886112d481.txt
# Removing: dataset/images/ringworn-skin-Copy_jpg.rf.5e75e54588b702604fedb3886112d481.jpg
# Removing: dataset/labels/1592-1-Copy_jpg.rf.af1ae61e264b447ae91e44c6157635d0.txt
# Removing: dataset/images/1592-1-Copy_jpg.rf.af1ae61e264b447ae91e44c6157635d0.jpg
# Removing: dataset/labels/GettyImages-956873768-ea2feab9d0ac433188b6dad426a6f300-Copy_jpg.rf.e368fb89416f4ccd27e413deb793c221.txt
# Removing: dataset/images/GettyImages-956873768-ea2feab9d0ac433188b6dad426a6f300-Copy_jpg.rf.e368fb89416f4ccd27e413deb793c221.jpg
# Removing: dataset/labels/pigmentation_0_7174-Copy_jpeg_jpg.rf.c6a5bf09f5c8776eae92cfde3819d5c0.txt
# Removing: dataset/images/pigmentation_0_7174-Copy_jpeg_jpg.rf.c6a5bf09f5c8776eae92cfde3819d5c0.jpg
# Removing: dataset/labels/dsd-Copy_PNG_jpg.rf.729ee6a98ba85c9880a3b51209d1e5ee.txt
# Removing: dataset/images/dsd-Copy_PNG_jpg.rf.729ee6a98ba85c9880a3b51209d1e5ee.jpg
# Removing: dataset/labels/wart-fili__WatermarkedWyJXYXRlcm1hcmtlZCJd-Copy_jpg.rf.2b8cbffbc6e154414fd403d77853e48e.txt
# Removing: dataset/images/wart-fili__WatermarkedWyJXYXRlcm1hcmtlZCJd-Copy_jpg.rf.2b8cbffbc6e154414fd403d77853e48e.jpg
# Removing: dataset/labels/LD-6-_jpg.rf.908e6cf9c02404e7c7e143fdc0202750.txt
# Removing: dataset/images/LD-6-_jpg.rf.908e6cf9c02404e7c7e143fdc0202750.jpg
# Removing: dataset/labels/erythema-migrans27_png_jpg.rf.72accaa89f01719d582da64b9fdcce65.txt
# Removing: dataset/images/erythema-migrans27_png_jpg.rf.72accaa89f01719d582da64b9fdcce65.jpg
# Removing: dataset/labels/7_33_jpg.rf.dcc06a793fd94aa6b31763bacda7e1cb.txt
# Removing: dataset/images/7_33_jpg.rf.dcc06a793fd94aa6b31763bacda7e1cb.jpg
# Removing: dataset/labels/7_1_jpg.rf.738caea98a90e96fddd3b3453f9d5919.txt
# Removing: dataset/images/7_1_jpg.rf.738caea98a90e96fddd3b3453f9d5919.jpg
# Removing: dataset/labels/KP-2-_jpg.rf.e075d1313a85bb97ee94ad6431e310e5.txt
# Removing: dataset/images/KP-2-_jpg.rf.e075d1313a85bb97ee94ad6431e310e5.jpg
# Removing: dataset/labels/viral-wart-13__WatermarkedWyJXYXRlcm1hcmtlZCJd-Copy_jpg.rf.ef447d76cf74f14ea0d322f8c7227771.txt
# Removing: dataset/images/viral-wart-13__WatermarkedWyJXYXRlcm1hcmtlZCJd-Copy_jpg.rf.ef447d76cf74f14ea0d322f8c7227771.jpg
# Removing: dataset/labels/Capture_PNG_jpg.rf.6a1ccd132e22fb7fbaac9ffaee0edc8b.txt
# Removing: dataset/images/Capture_PNG_jpg.rf.6a1ccd132e22fb7fbaac9ffaee0edc8b.jpg

# %%
import os
from pathlib import Path

# Count files in all splits
splits = ['train', 'test', 'valid']
total_labels = 0
total_images = 0

print("File counts by split:")
print("=" * 50)

for split in splits:
    labels_path = Path(f'./{split}/labels')
    images_path = Path(f'./{split}/images')
    
    if labels_path.exists() and images_path.exists():
        label_count = len([f for f in os.listdir(labels_path) if os.path.isfile(os.path.join(labels_path, f))])
        image_count = len([f for f in os.listdir(images_path) if os.path.isfile(os.path.join(images_path, f))])
        
        print(f"{split.upper()}:")
        print(f"  Labels: {label_count}")
        print(f"  Images: {image_count}")
        print(f"  Match: {'✅' if label_count == image_count else '❌'}")
        
        total_labels += label_count
        total_images += image_count
    else:
        print(f"{split.upper()}: Not found")

print("=" * 50)
print(f"TOTAL:")
print(f"  Labels: {total_labels}")
print(f"  Images: {total_images}")
print(f"  Match: {'✅' if total_labels == total_images else '❌'}")
# Out:
# Labels count: 321
# Images count: 321

# %%
import os
from pathlib import Path

# Process all splits: train, test, valid
splits = ['train', 'test', 'valid']
prefix = "00000"  # Change this prefix as needed

for split in splits:
    labels_path = Path(f'./{split}/labels')
    images_path = Path(f'./{split}/images')
    
    for folder in [labels_path, images_path]:
        if folder.exists():
            print(f"Renaming files in: {folder}")
            
            files = [f for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))]
            for filename in files:
                old_path = os.path.join(folder, filename)
                new_filename = prefix + filename
                new_path = os.path.join(folder, new_filename)
                
                os.rename(old_path, new_path)
            
            print(f"  ✅ Renamed {len(files)} files")
        else:
            print(f"  ❌ Path not found: {folder}")

print("\nDone renaming all files!")
# Out:
# Renaming files in: /home/ksan/Documents/my-projects/thesis/segmentation-fr/segmentation-thermal-burns/dataset/healthyskin/dataset/labels
# Done.
# Renaming files in: /home/ksan/Documents/my-projects/thesis/segmentation-fr/segmentation-thermal-burns/dataset/healthyskin/dataset/images
# Done.
